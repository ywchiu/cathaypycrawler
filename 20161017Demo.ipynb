# %% [markdown]
# ## 抓取PTT Creditcard 板

# %%
import requests
res = requests.get('https://www.ptt.cc/bbs/creditcard/index.html')
#print(res.text)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, 'html.parser')
for rent in soup.select('.r-ent'):
    #print(rent)
    #print('=======================')
    title  = rent.select('.title')[0].text.strip()
    date   = rent.select('.date')[0].text.strip()
    author = rent.select('.author')[0].text.strip()
    nrec  = rent.select('.nrec')[0].text.strip()
    print(title, date, author, nrec)
# Out:
# [心得] 國泰長榮極致無限卡核卡 10/17 ThreeComma 6
# [問題] 樂天最新優惠活動 10/17 LBJKDPG 7
# [心得] 富邦/數位生活/御璽/小白 核卡 10/17 rjhowmanyo 3
# (本文已被刪除) [kathyandyy] 10/17 -
# [問題] 酷玩卡值得辦嗎？ 10/17 daniel820 16
# Re: [心得] 搭乘計程車 刷信用卡優惠整理 10/17 neon7134 11
# [心得] 永豐 Me Card 鈦金卡核卡 10/17 Robbins 9
# [問題] 國泰亞萬卡在昇恆昌 10/17 ohhenry 2
# [心得] 在冰島使用花旗現金回饋白金卡分享 10/17 ppsj 15
# Re:  [心得] 在冰島使用花旗現金回饋白金卡分享 10/17 siriusc 10
# [問題] 秀泰聯名卡後續？ 10/17 n1lk5g2 6
# (本文已被刪除) [yungshengwu] 10/17 - 1
# === 卡板板規 V5.0 === (修訂日期：2012/10/02) 10/02 Heumay
# [公告] 置底檢舉專區 3/05 bboy0720 爆
# [情報] 各家銀行0800免付費電話 3/09 MoonAthenaX 34

# %% [markdown]
# ## 抓取PTT Gossiping 板 (方法一)

# %%
import requests
cookies = {
 'over18':'1'   
}
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', cookies = cookies)
#print(res.text)

# %% [markdown]
# ## 抓取PTT Gossiping 板 (方法二)

# %%
import requests
payload ={
'from':'/bbs/Gossiping/index.html',
'yes':'yes'    
}
rs   = requests.session()
res  = rs.post('https://www.ptt.cc/ask/over18', data = payload)
res2 = rs.get('https://www.ptt.cc/bbs/Gossiping/index.html')
#print(res2.text)

# %% [markdown]
# ## 抓取 CK101 (加上Headers)

# %%
import requests
headers = {
'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.143 Safari/537.36'    
}
res = requests.get('http://ck101.com/', headers = headers)
#print(res.text)
#print(res.request.prepare_headers)

# %% [markdown]
# ## 抓取動漫王圖片 (使用shutil, PIL)

# %%
import requests
import shutil
res = requests.get('http://web4.cartoonmad.com/c86eo736r62/1152/842/001.jpg', stream=True)
with open('001.jpg', 'wb') as f:
    shutil.copyfileobj(res.raw, f)

# %%
from PIL import Image
Image.open('001.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=850x1350 at 0x51305F8>

# %% [markdown]
# ## Selenium
# - https://addons.mozilla.org/en-US/firefox/addon/selenium-ide/
# - https://github.com/mozilla/geckodriver/releases

# %%
# -*-coding: utf-8 -*-
from selenium import webdriver 
import time
driver=webdriver.Firefox()
driver.implicitly_wait(30)
base_url="https://www.facebook.com/"
driver.get(base_url)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      63                                             close_fds=platform.system() != 'Windows',
# ---> 64                                             stdout=self.log_file, stderr=self.log_file)
#      65         except TypeError:
#
# C:\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     946                                 errread, errwrite,
# --> 947                                 restore_signals, start_new_session)
#     948         except:
#
# C:\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1223                                          cwd,
# -> 1224                                          startupinfo)
#    1225             finally:
#
# FileNotFoundError: [WinError 2] 系統找不到指定的檔案。
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-18-45173d657de7> in <module>()
#       2 from selenium import webdriver
#       3 import time
# ----> 4 driver=webdriver.Firefox()
#       5 driver.implicitly_wait(30)
#       6 base_url="https://www.facebook.com/"
#
# C:\Anaconda3\lib\site-packages\selenium\webdriver\firefox\webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, firefox_options, log_path)
#     133         if capabilities.get("marionette"):
#     134             self.service = Service(executable_path, log_path=log_path)
# --> 135             self.service.start()
#     136
#     137             capabilities.update(firefox_options.to_capabilities())
#
# C:\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      69                 raise WebDriverException(
#      70                     "'%s' executable needs to be in PATH. %s" % (
# ---> 71                         os.path.basename(self.path), self.start_error_message)
#      72                 )
#      73             elif err.errno == errno.EACCES:
#
# WebDriverException: Message: 'geckodriver' executable needs to be in PATH.
